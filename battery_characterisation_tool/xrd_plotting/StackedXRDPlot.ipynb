# %% [markdown]
# ## Stacked XRD Plot

# %%
#Code from stack overflow:

import numpy as np 
import matplotlib.pyplot as plt 
 
x = np.linspace(0, 6.28, 629) 
y = np.sin(x)*np.exp(-0.8*x)                                                      

for n in range(5): 
    plt.plot(x, y+n) 
plt.yticks([]) ; plt.show()

# %%
P2_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_JSZW.asc')
P2_Ca121_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\P2_Ca121.asc')
P2Ca127_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_Ca127.asc')
x_P2 = P2_data[:, 0]
y_obs_P2 = P2_data[:, 1]
y_calc_P2 = P2_data[:, 2]
x_P2Ca121 = P2Ca121_data[:, 0]
y_obs_P2Ca121 = P2Ca121_data[:, 1]
y_calc_P2Ca121 = P2Ca121_data[:, 2]
x_P2Ca127 = P2Ca127_data[:, 0]
y_obs_P2Ca127 = P2Ca127_data[:, 1]
y_calc_P2Ca127 = P2Ca127_data[:, 2]

# %%
# Load data
P2_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_JSZW.asc')
P2Ca121_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\P2_Ca121.asc')
P2Ca127_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_Ca127.asc')

x_P2, y_obs_P2, y_calc_P2 = P2_data[:, 0], P2_data[:, 1], P2_data[:, 2]
x_P2Ca121, y_obs_P2Ca121, y_calc_P2Ca121 = P2Ca121_data[:, 0], P2Ca121_data[:, 1], P2Ca121_data[:, 2]
x_P2Ca127, y_obs_P2Ca127, y_calc_P2Ca127 = P2Ca127_data[:, 0], P2Ca127_data[:, 1], P2Ca127_data[:, 2]

# Plotting
fig, axs = plt.subplots(3, 1, figsize=(8, 12), sharex=True)

# Plot 1: P2
axs[0].plot(x_P2, y_obs_P2, label='Observed P2', color='blue')
axs[0].plot(x_P2, y_calc_P2, label='Calculated P2', linestyle='--', color='red')
axs[0].legend()
axs[0].set_ylabel('Intensity')
axs[0].set_title('P2 Data')

# Plot 2: P2_Ca121
axs[1].plot(x_P2Ca121, y_obs_P2Ca121, label='Observed P2_Ca121', color='blue')
axs[1].plot(x_P2Ca121, y_calc_P2Ca121, label='Calculated P2_Ca121', linestyle='--', color='red')
axs[1].legend()
axs[1].set_ylabel('Intensity')
axs[1].set_title('P2_Ca121 Data')

# Plot 3: P2Ca127
axs[2].plot(x_P2Ca127, y_obs_P2Ca127, label='Observed P2Ca127', color='blue')
axs[2].plot(x_P2Ca127, y_calc_P2Ca127, label='Calculated P2Ca127', linestyle='--', color='red')
axs[2].legend()
axs[2].set_xlabel(r'2$\theta$ / °')
axs[2].set_ylabel('Intensity')
axs[2].set_title('P2Ca127 Data')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
#P2P3
y = np.array([3.99, 41.99, 54.03])
mycolors= ['#e6ab02', '#e7298a', '#7570b3']
plt.pie(y, colors=mycolors)
plt.legend(labels=['NiO','P2', 'P3'], fontsize=16, bbox_to_anchor=(1,1))
plt.show()

# %%
y = np.array([1.88, 98.12])
mycolors= ['#e6ab02', '#7570b3']
plt.pie(y, colors=mycolors)
plt.legend(labels=['NiO','P2'], fontsize=16, bbox_to_anchor=(1,1))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load data
P2_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_JSZW.asc')
P2_Ca121_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\P2_Ca121.asc')
P2Ca127_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_Ca127.asc')

x_P2, y_obs_P2, y_calc_P2 = P2_data[:, 0], P2_data[:, 1], P2_data[:, 2]
x_P2Ca121, y_obs_P2Ca121, y_calc_P2Ca121 = P2Ca121_data[:, 0], P2Ca121_data[:, 1], P2Ca121_data[:, 2]
x_P2Ca127, y_obs_P2Ca127, y_calc_P2Ca127 = P2Ca127_data[:, 0], P2Ca127_data[:, 1], P2Ca127_data[:, 2]

# Set offset values
offset_P2 = 0
offset_P2Ca121 = 2000000  # Adjust this value as needed
offset_P2Ca127 = 4000000  # Adjust this value as needed



# Plotting
plt.figure(figsize=(10, 6))

# Plot 1: P2
plt.plot(x_P2, y_obs_P2 + offset_P2, label='Observed P2', color='blue')
plt.plot(x_P2, y_calc_P2 + offset_P2, label='Calculated P2', linestyle='--', color='red')

# Plot 2: P2_Ca121
plt.plot(x_P2Ca121, y_obs_P2Ca121 + offset_P2Ca121, label='Observed P2_Ca121', color='green')
plt.plot(x_P2Ca121, y_calc_P2Ca121 + offset_P2Ca121, label='Calculated P2_Ca121', linestyle='--', color='orange')

# Plot 3: P2Ca127
plt.plot(x_P2Ca127, y_obs_P2Ca127 + offset_P2Ca127, label='Observed P2Ca127', color='purple')
plt.plot(x_P2Ca127, y_calc_P2Ca127 + offset_P2Ca127, label='Calculated P2Ca127', linestyle='--', color='brown')

#Set x-axis limit
plt.xlim(5, 45)
plt.ylim(-100,8000000)

# Adjust labels and legend
plt.xlabel(r'2$\theta$ / °', fontsize=16)
plt.ylabel('Intensity', fontsize=16)
plt.title('Ca doped P2-NNMO Series', fontsize=16)
plt.legend(bbox_to_anchor=(1, 1.05), loc='upper left')

# Show the plot
plt.show()
#plt.savefig('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\I11 Data\\March 2023\\Python figures\\Stacked_XRD_plot.png', dpi=300)

# %%
#Plot logy for better intensity matching
import numpy as np
import matplotlib.pyplot as plt

# Load data
P2_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_JSZW.asc')
P2_Ca121_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\P2_Ca121.asc')
P2Ca127_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_Ca127.asc')

x_P2, y_obs_P2, y_calc_P2 = P2_data[:, 0], P2_data[:, 1], P2_data[:, 2]
x_P2Ca121, y_obs_P2Ca121, y_calc_P2Ca121 = P2Ca121_data[:, 0], P2Ca121_data[:, 1], P2Ca121_data[:, 2]
x_P2Ca127, y_obs_P2Ca127, y_calc_P2Ca127 = P2Ca127_data[:, 0], P2Ca127_data[:, 1], P2Ca127_data[:, 2]

# Set offset values
offset_P2 = 0
offset_P2Ca121 = 2000000  # Adjust this value as needed
offset_P2Ca127 = 4000000  # Adjust this value as needed


# Plotting
plt.figure(figsize=(10, 6))

# Plot 1: P2
plt.plot(x_P2, y_obs_P2 + offset_P2, label='Observed P2', color='blue')
plt.plot(x_P2, y_calc_P2 + offset_P2, label='Calculated P2', linestyle='--', color='red')

# Plot 2: P2_Ca121
plt.plot(x_P2Ca121, y_obs_P2Ca121 + offset_P2Ca121, label='Observed P2_Ca121', color='green')
plt.plot(x_P2Ca121, y_calc_P2Ca121 + offset_P2Ca121, label='Calculated P2_Ca121', linestyle='--', color='orange')

# Plot 3: P2Ca127
plt.plot(x_P2Ca127, y_obs_P2Ca127 + offset_P2Ca127, label='Observed P2Ca127', color='purple')
plt.plot(x_P2Ca127, y_calc_P2Ca127 + offset_P2Ca127, label='Calculated P2Ca127', linestyle='--', color='brown')

#Set x-axis limit
plt.xlim(5, 45)
plt.ylim(-100,6200000)

# Adjust labels and legend
plt.xlabel(r'2$\theta$ / °', fontsize=16)
plt.ylabel('Intensity', fontsize=16)
plt.title('Ca doped P2-NNMO Series', fontsize=16)
plt.legend(bbox_to_anchor=(1, 1.05), loc='upper left')

# Show the plot
plt.show()
#plt.savefig('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\I11 Data\\March 2023\\Python figures\\Stacked_XRD_plot.png', dpi=300)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load data
P2_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_JSZW.asc')
P2_Ca121_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\P2_Ca121.asc')
P2Ca127_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_Ca127.asc')

x_P2, y_obs_P2, y_calc_P2 = P2_data[:, 0], P2_data[:, 1], P2_data[:, 2]
x_P2Ca121, y_obs_P2Ca121, y_calc_P2Ca121 = P2Ca121_data[:, 0], P2Ca121_data[:, 1], P2Ca121_data[:, 2]
x_P2Ca127, y_obs_P2Ca127, y_calc_P2Ca127 = P2Ca127_data[:, 0], P2Ca127_data[:, 1], P2Ca127_data[:, 2]

# Set offset values
offset_P2 = 0
offset_P2Ca121 = 200  # Adjust this value as needed
offset_P2Ca127 = 400  # Adjust this value as needed

# Plotting
fig, axes = plt.subplots(3, 1, figsize=(10, 18), sharex=True)

# Plot 1: P2
axes[0].plot(x_P2, y_obs_P2 + offset_P2, label='Observed P2', color='black', linewidth = 2)
axes[0].plot(x_P2, y_calc_P2 + offset_P2, label='Calculated P2', linestyle='--', color='red')
axes[0].set_ylabel('Intensity')
axes[0].set_xlabel(r'2$\theta$ / °')
axes[0].legend()

# Plot 2: P2_Ca121
axes[1].plot(x_P2Ca121, y_obs_P2Ca121 + offset_P2Ca121, label='Observed P2-Ca1/21', color='black', )
axes[1].plot(x_P2Ca121, y_calc_P2Ca121 + offset_P2Ca121, label='Calculated P2-Ca1/21', linestyle='--', color='red')
axes[1].set_ylabel('Intensity')
axes[1].set_xlabel(r'2$\theta$ / °')
axes[1].legend()

# Plot 3: P2Ca127
axes[2].plot(x_P2Ca127, y_obs_P2Ca127 + offset_P2Ca127, label='Observed P2-Ca1/27', color='black')
axes[2].plot(x_P2Ca127, y_calc_P2Ca127 + offset_P2Ca127, label='Calculated P2-Ca1/27', linestyle='--', color='red')
axes[2].set_xlabel(r'2$\theta$ / °')
axes[2].set_ylabel('Intensity')
axes[2].legend()

# Set x-axis limit
plt.xlim(5, 60)  # Replace x_min and x_max with your desired limits

# Set y-axis to logarithmic scale for all subplots
for ax in axes:
    ax.set_yscale('log')

# Adjust title
#plt.suptitle('Stacked Data with Offset (log scale)', fontsize=16)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load data
P2_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_JSZW.asc')
P2Ca121_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\P2_Ca121.asc')
P2Ca127_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_Ca127.asc')

# Load ticks Data
data_ticks_x_NiO = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_Ca127_ticks_NiO.tic')[:, 0]
#data_ticks_x_P2_Or = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\P2_JSZW_ticks_Or.tic')[:, 0]
data_ticks_x_P2_narrow = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_Ca127_ticks_P2_narrow.tic')[:, 0]
data_ticks_x_P2_broad_odd = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_Ca127_ticks_P2_broad_odd.tic')[:, 0]
data_ticks_x_P2_broad_even = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_Ca127_ticks_P2_broad_even.tic')[:, 0]

x_P2, y_obs_P2, y_calc_P2 = P2_data[:, 0], P2_data[:, 1], P2_data[:, 2]
x_P2Ca121, y_obs_P2Ca121, y_calc_P2Ca121 = P2Ca121_data[:, 0], P2Ca121_data[:, 1], P2Ca121_data[:, 2]
x_P2Ca127, y_obs_P2Ca127, y_calc_P2Ca127 = P2Ca127_data[:, 0], P2Ca127_data[:, 1], P2Ca127_data[:, 2]

# Set offset values
offset_P2 = 500 #80000
offset_P2Ca121 = 2000 #500000  # Adjust this value as needed
offset_P2Ca127 = 4000 #1200000 # Adjust this value as needed

# Plotting
plt.figure(figsize=(7, 6))

# Plot 1: P2
plt.plot(x_P2, np.sqrt(y_obs_P2) + offset_P2, label='Observed P2', linewidth = 0.5, color='black')
plt.plot(x_P2, np.sqrt(y_calc_P2) + offset_P2, label='Calculated P2', linestyle='--', color='plum')

# Plot 2: P2_Ca121
plt.plot(x_P2Ca121, np.sqrt(y_obs_P2Ca121) + offset_P2Ca121, label='Observed P2-Ca1/21', linewidth = 1, color='black')
plt.plot(x_P2Ca121, np.sqrt(y_calc_P2Ca121) + offset_P2Ca121, label='Calculated P2-Ca1/21', linestyle='--', color='mediumturquoise')

# Plot 3: P2Ca127
plt.plot(x_P2Ca127, np.sqrt(y_obs_P2Ca127) + offset_P2Ca127, label='Observed P2-Ca1/27', linewidth = 1, color='black')
plt.plot(x_P2Ca127, np.sqrt(y_calc_P2Ca127) + offset_P2Ca127, label='Calculated P2-Ca1/27', linestyle='--', color='darkseagreen') 

# Plot ticks (P2)
plt.scatter(data_ticks_x_NiO, [100 for x in data_ticks_x_NiO], marker='|', label='NiO')
#plt.scatter(data_ticks_x_P2_Or, [250 for x in data_ticks_x_P2_Or], marker='|', label='P2_Or')
plt.scatter(data_ticks_x_P2_narrow, [250 for x in data_ticks_x_P2_narrow], marker='|', label='P2', color = 'red') #Narrow')
plt.scatter(data_ticks_x_P2_broad_odd, [250 for x in data_ticks_x_P2_broad_odd], marker='|', color ='red') # Broad Odd')
plt.scatter(data_ticks_x_P2_broad_even, [250 for x in data_ticks_x_P2_broad_even], marker='|', color = 'red') # Broad Even') #label='P2',

# Set x-axis limit
plt.xlim(5, 60)  # Replace x_min and x_max with your desired limits
plt.ylim(0, 6500) #100000,0 (4e4, 6e6) 

# Set y-axis to logarithmic scale
#plt.yscale('log')
#plt.yscale('sqrt')

# Adjust labels and legend
plt.xlabel(r'2$\theta$ / °', fontsize=16)
plt.ylabel('Intensity sqrt(y)', fontsize=16)
plt.title('Ca doped P2 Series', fontsize=16)
plt.legend(bbox_to_anchor=(0.207, 1), loc='upper left', ncol=2)


# Show the plot
plt.show()
#plt.savefig(r'C:\Users\chem-exet5737\OneDrive - Nexus365\RAL\Rietveld Refinement\240311_P2vsP2P3 Ca-doped Materials (ECR conference)\Figures\P2_NNMO_Stacked_XRD_plot_sqrty.png', dpi=300, bbox_inches='tight')

# %%
df = np.genfromtxt(r'C:\Users\chem-exet5737\OneDrive - Nexus365\I11 Data\Jan 2024\P2P3Ca272.asc')
df[0]
# Out:
# array([3.00000000e+00, 9.49791732e+04, 9.52186970e+04])

# %%
import matplotlib.pyplot as plt
import numpy as np

#P2
y = np.array([0.19, 99.81])
mycolors= ['#e6ab02', '#7570b3']
labels = "NiO", "P2"
plt.pie(y, colors=mycolors)
#plt.labels() 
#plt.title("P2")
#plt.axis('equal')
# Out:
# ([<matplotlib.patches.Wedge at 0x20fd479d940>,
# ...
#  [Text(1.0999804039579837, 0.006565889766907642, ''),
#   Text(-1.0999804043133803, -0.0065658302272025865, '')])

# %%
#P2Ca127
y = np.array([1.83, 98.16])
mycolors= ['#e6ab02', '#7570b3']
plt.pie(y, colors=mycolors)
plt.show()

# %%
#P2Ca121
y = np.array([1.88, 98.12])
mycolors= ['#e6ab02', '#7570b3']
plt.pie(y, colors=mycolors)
plt.show()

# %%
#P2P3
y = np.array([3.99, 41.99, 54.03])
mycolors= ['#e6ab02', '#e7298a', '#7570b3']
plt.pie(y, colors=mycolors)
plt.legend(labels=['NiO','P2', 'P3'], fontsize=16, bbox_to_anchor=(1,1))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

val1 = 3.99
val2 = 41.99
val3 = 54.03
val4 = 10
val5 = 4
n_colors=5

y = np.array([val1, val2, val3, val4, val5])
mycolors = sns.color_palette('Dark2', n_colors)
plt.pie(y, colors=mycolors)
plt.legend(labels=['NiO','P2', 'P3', '4', '5'], fontsize=16, bbox_to_anchor=(1,1))
plt.show()

# %%
#P2P3Ca272
y = np.array([3.03, 51.61, 45.80])
mycolors= ['#e6ab02', '#e7298a', '#7570b3']
plt.pie(y, colors=mycolors)
plt.show()

# %%
#P2P3Ca272
y = np.array([3.51, 59.37, 37.13])
mycolors= ['#e6ab02', '#e7298a', '#7570b3']
plt.pie(y, colors=mycolors)
plt.show()

# %%
import seaborn as sns
pal = sns.color_palette('Dark2')
x = pal.as_hex()
print(x)
# Out:
# ['#1b9e77', '#d95f02', '#7570b3', '#e7298a', '#66a61e', '#e6ab02', '#a6761d', '#666666']

# %%
import numpy as np
import matplotlib.pyplot as plt

P2P3_data = np.loadtxt(r'C:\Users\chem-exet5737\OneDrive - Nexus365\I11 Data\Jan 2024\P2P3.asc')

data_ticks_x_NiO = np.loadtxt(r'C:\Users\chem-exet5737\OneDrive - Nexus365\I11 Data\Jan 2024\NiO_Ca272_ticks.asc')[:, 0]
data_ticks_x_P2 = np.loadtxt(r'C:\Users\chem-exet5737\OneDrive - Nexus365\I11 Data\Jan 2024\P2_Ca272_ticks.asc')[:, 0]
data_ticks_x_P3 = np.loadtxt(r'C:\Users\chem-exet5737\OneDrive - Nexus365\I11 Data\Jan 2024\P3_Ca272_ticks.asc')[:, 0]

x_P2P3, y_calc_P2P3, y_obs_P2P3 = P2P3_data[:, 0], P2P3_data[:, 1], P2P3_data[:, 2]

#offset_P2P3 = 300

plt.figure(figsize=(4, 6))

# Plot 1: P2P3
plt.plot(x_P2P3, np.sqrt(y_obs_P2P3) + offset_P2P3, label=' P2P3', linewidth = 0.5, color='black')
plt.plot(x_P2P3, np.sqrt(y_calc_P2P3) + offset_P2P3, label='Calculated P2P3', linestyle='--', color='plum')

#plt.scatter(data_ticks_x_NiO, [100 for x in data_ticks_x_NiO], marker='|', label='NiO', color='blue')
#plt.scatter(data_ticks_x_P2, [200 for x in data_ticks_x_P2], marker='|', label='P2', color = 'red')
##plt.scatter(data_ticks_x_P3, [300 for x in data_ticks_x_P3], marker='|', label='P3', color ='green')

plt.xlim(21.5, 22.7)  # Replace x_min and x_max with your desired limits
plt.ylim(400, 1450)

plt.xlabel(r'2$\theta$ / °', fontsize=16)
plt.ylabel('Intensity sqrt(y)', fontsize=16)
#plt.title('Ca doped P2P3 Series', fontsize=16)
#plt.xticks(fontsize=16)
#plt.yticks(fontsize=16)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load data
P2P3_data = np.loadtxt(r'C:\Users\chem-exet5737\OneDrive - Nexus365\I11 Data\Jan 2024\P2P3.asc')
P2P3Ca272_data = np.loadtxt(r'C:\Users\chem-exet5737\OneDrive - Nexus365\I11 Data\Jan 2024\P2P3Ca272.asc')
P2P3Ca372_data = np.loadtxt(r'C:\Users\chem-exet5737\OneDrive - Nexus365\I11 Data\Jan 2024\P2P3Ca372.asc')

# Load ticks Data
data_ticks_x_NiO = np.loadtxt(r'C:\Users\chem-exet5737\OneDrive - Nexus365\I11 Data\Jan 2024\NiO_Ca272_ticks.asc')[:, 0]
data_ticks_x_P2 = np.loadtxt(r'C:\Users\chem-exet5737\OneDrive - Nexus365\I11 Data\Jan 2024\P2_Ca272_ticks.asc')[:, 0]
data_ticks_x_P3 = np.loadtxt(r'C:\Users\chem-exet5737\OneDrive - Nexus365\I11 Data\Jan 2024\P3_Ca272_ticks.asc')[:, 0]

x_P2P3, y_calc_P2P3, y_obs_P2P3 = P2P3_data[:, 0], P2P3_data[:, 1], P2P3_data[:, 2]
x_P2P3Ca272, y_calc_P2P3Ca272, y_obs_P2P3Ca272 = P2P3Ca272_data[:, 0], P2P3Ca272_data[:, 1], P2P3Ca272_data[:, 2]
x_P2P3Ca372, y_calc_P2P3Ca372, y_obs_P2P3Ca372 = P2P3Ca372_data[:, 0], P2P3Ca372_data[:, 1], P2P3Ca372_data[:, 2]

# Set offset values
offset_P2P3 = 300 #80000
offset_P2P3Ca272 = 1400 #500000  # Adjust this value as needed
offset_P2P3Ca372 = 2600 #1200000 # Adjust this value as needed

# Plotting
plt.figure(figsize=(9, 6))

# Plot 1: P2P3
plt.plot(x_P2P3, np.sqrt(y_obs_P2P3) + offset_P2P3, label='Observed P2P3', linewidth = 0.5, color='black')
plt.plot(x_P2P3, np.sqrt(y_calc_P2P3) + offset_P2P3, label='Calculated P2P3', linestyle='--', color='plum')
#legend1 = plt.legend(bbox_to_anchor=(0.75, 1), loc='upper left')

# Plot 2: P2P3Ca272
plt.plot(x_P2P3Ca272, np.sqrt(y_obs_P2P3Ca272) + offset_P2P3Ca272, label='Observed P2P3Ca2/72', linewidth = 1, color='black')
plt.plot(x_P2P3Ca272, np.sqrt(y_calc_P2P3Ca272) + offset_P2P3Ca272, label='Calculated P2P3Ca2/72', linestyle='--', color='mediumturquoise')
#legend2 = plt.legend(bbox_to_anchor=(0.5, 1), loc='upper left')

# Plot 3: P2P3Ca372
plt.plot(x_P2P3Ca372, np.sqrt(y_obs_P2P3Ca372) + offset_P2P3Ca372, label='Observed P2P3Ca3/72', linewidth = 1, color='black')
plt.plot(x_P2P3Ca372, np.sqrt(y_calc_P2P3Ca372) + offset_P2P3Ca372, label='Calculated P2P3Ca3/72', linestyle='--', color='darkseagreen') 
#legend3 = plt.legend(bbox_to_anchor=(0.25, 1), loc='upper left')

# Plot ticks 
plt.scatter(data_ticks_x_NiO, [100 for x in data_ticks_x_NiO], marker='|', label='NiO', color='blue')
plt.scatter(data_ticks_x_P2, [200 for x in data_ticks_x_P2], marker='|', label='P2', color = 'red')
plt.scatter(data_ticks_x_P3, [300 for x in data_ticks_x_P3], marker='|', label='P3', color ='green')


# Set x-axis limit
plt.xlim(5, 59.6)  # Replace x_min and x_max with your desired limits
plt.ylim(0, 4000) #100000,0 (4e4, 6e6) 

# Set y-axis to logarithmic scale
#plt.yscale('log')
#plt.yscale('sqrt')

# Adjust labels and legend
plt.xlabel(r'2$\theta$ / °', fontsize=16)
plt.ylabel('Intensity sqrt(y)', fontsize=16)
plt.title('Ca doped P2P3 Series', fontsize=16)
plt.xticks(fontsize=20)
#plt.yticks(fontsize=20)
#plt.legend(bbox_to_anchor=(0.4, 1), loc='upper left', ncol=3)

legend_P2P3 = plt.legend(['Observed P2P3', 'Calculated P2P3'], loc='upper left', bbox_to_anchor=(0.77, 0.35), labelcolor=['black', 'plum'], handlelength=0)
plt.gca().add_artist(legend_P2P3)
legend_P2P3Ca272 = plt.legend(['Observed P2P3Ca2/72', 'Calculated P2P3Ca2/72'], loc='upper left', bbox_to_anchor=(0.7, 0.65), labelcolor=['black', 'mediumturquoise'], handlelength=0)
plt.gca().add_artist(legend_P2P3Ca272)
legend_P2P3Ca372 = plt.legend(['Observed P2P3Ca3/72', 'Calculated P2P3Ca3/72'], loc='upper left', bbox_to_anchor=(0.7, 1), labelcolor=['black', 'darkseagreen'], handlelength=0)
plt.gca().add_artist(legend_P2P3Ca372)
legend_ticks = plt.legend(['P3', 'P2', 'NiO'], loc='upper left', bbox_to_anchor=(1, 0.155), labelcolor=['green','red', 'blue'], handlelength=0)
plt.gca().add_artist(legend_P2P3)
# Add legends to the plot



"""
proxy_P2P3 = plt.Line2D([0], [0], linestyle='None', marker='-', markersize=10, color='black')
proxy_P2P3Ca272 = plt.Line2D([0], [0], linestyle='None', marker='-', markersize=10, color='mediumturquoise')
proxy_P2P3Ca372 = plt.Line2D([0], [0], linestyle='None', marker='-', markersize=10, color='darkseagreen')

# Manually create legend for each group of data with proxy artists
legend_P2P3 = plt.legend([proxy_P2P3], ['P2P3'], loc='upper left', bbox_to_anchor=(0.75, 1))
legend_P2P3Ca272 = plt.legend([proxy_P2P3Ca272], ['P2P3Ca2/72'], loc='upper left', bbox_to_anchor=(0.68, 0.6))
legend_P2P3Ca372 = plt.legend([proxy_P2P3Ca372], ['P2P3Ca3/72'], loc='upper left', bbox_to_anchor=(0.68, 0.3))

# Add legends to the plot
plt.gca().add_artist(legend_P2P3)
plt.gca().add_artist(legend_P2P3Ca272)
plt.gca().add_artist(legend_P2P3Ca372)
"""
# Show the plot
plt.show()

# %%
# Load data
P2_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_JSZW.asc')
P2Ca127_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_Ca127.asc')
P2Ca121_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\P2_Ca121.asc')


# Load ticks Data
data_ticks_x_NiO = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_Ca127_ticks_NiO.tic')[:, 0]
#data_ticks_x_P2_Or = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\P2_JSZW_ticks_Or.tic')[:, 0]
data_ticks_x_P2_narrow = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_Ca127_ticks_P2_narrow.tic')[:, 0]
data_ticks_x_P2_broad_odd = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_Ca127_ticks_P2_broad_odd.tic')[:, 0]
data_ticks_x_P2_broad_even = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_Ca127_ticks_P2_broad_even.tic')[:, 0]

x_P2, y_calc_P2, y_obs_P2 = P2_data[:, 0], P2_data[:, 1], P2_data[:, 2]
x_P2Ca121, y_calc_P2Ca121, y_obs_P2Ca121 = P2Ca121_data[:, 0], P2Ca121_data[:, 1], P2Ca121_data[:, 2]
x_P2Ca127, y_calc_P2Ca127, y_obs_P2Ca127 = P2Ca127_data[:, 0], P2Ca127_data[:, 1], P2Ca127_data[:, 2]

# Set offset values
offset_P2 = 300
offset_P2Ca127 = 1700  # Adjust this value as needed
offset_P2Ca121 = 3500 # Adjust this value as needed

# Plotting
plt.figure(figsize=(9, 6))

# Plot 1: P2P3
plt.plot(x_P2, np.sqrt(y_obs_P2) + offset_P2, label='Observed P2', linewidth = 0.5, color='black')
plt.plot(x_P2, np.sqrt(y_calc_P2) + offset_P2, label='Calculated P2', linestyle='--', color='plum')


# Plot 2: P2P3Ca272
plt.plot(x_P2Ca127, np.sqrt(y_obs_P2Ca127) + offset_P2Ca127, label='Observed P2Ca1/27', linewidth = 1, color='black')
plt.plot(x_P2Ca127, np.sqrt(y_calc_P2Ca127) + offset_P2Ca127, label='Calculated P2Ca1/27', linestyle='--', color='mediumturquoise')
#legend2 = plt.legend(bbox_to_anchor=(0.5, 1), loc='upper left')

# Plot 3: P2P3Ca372
plt.plot(x_P2Ca121, np.sqrt(y_obs_P2Ca121) + offset_P2Ca121, label='Observed P2Ca1/21', linewidth = 1, color='black')
plt.plot(x_P2Ca121, np.sqrt(y_calc_P2Ca121) + offset_P2Ca121, label='Calculated P2Ca1/21', linestyle='--', color='darkseagreen') 
#legend3 = plt.legend(bbox_to_anchor=(0.25, 1), loc='upper left')

# Plot ticks 
plt.scatter(data_ticks_x_NiO, [100 for x in data_ticks_x_NiO], marker='|', label='NiO', color='blue')
plt.scatter(data_ticks_x_P2_narrow, [200 for x in data_ticks_x_P2_narrow], marker='|', label='P2', color = 'red') #Narrow')
plt.scatter(data_ticks_x_P2_broad_odd, [200 for x in data_ticks_x_P2_broad_odd], marker='|', color ='red') # Broad Odd')
plt.scatter(data_ticks_x_P2_broad_even, [200 for x in data_ticks_x_P2_broad_even], marker='|', color = 'red') # Broad Even') #label='P2',


# Set x-axis limit
plt.xlim(5, 59.6)  # Replace x_min and x_max with your desired limits
plt.ylim(0, 5500) #100000,0 (4e4, 6e6) 

# Adjust labels and legend
plt.xlabel(r'2$\theta$ / °', fontsize=16)
plt.ylabel('Intensity sqrt(y)', fontsize=16)
plt.title('Ca doped P2 Series', fontsize=16)
plt.xticks(fontsize=20)
#plt.yticks(fontsize=20)
#plt.legend(bbox_to_anchor=(0.4, 1), loc='upper left', ncol=3)

legend_P2P3 = plt.legend(['Observed P2', 'Calculated P2'], loc='upper left', bbox_to_anchor=(0.77, 0.3), labelcolor=['black', 'plum'], handlelength=0)
plt.gca().add_artist(legend_P2P3)
legend_P2P3Ca272 = plt.legend(['Observed P2Ca1/27', 'Calculated P2Ca1/27'], loc='upper left', bbox_to_anchor=(0.7, 0.65), labelcolor=['black', 'mediumturquoise'], handlelength=0)
plt.gca().add_artist(legend_P2P3Ca272)
legend_P2P3Ca372 = plt.legend(['Observed P2Ca1/21', 'Calculated P2Ca1/21'], loc='upper left', bbox_to_anchor=(0.7, 1), labelcolor=['black', 'darkseagreen'], handlelength=0)
plt.gca().add_artist(legend_P2P3Ca372)
legend_ticks = plt.legend(['P2', 'NiO'], loc='upper left', bbox_to_anchor=(1, 0.115), labelcolor=['red', 'blue'], handlelength=0)
plt.gca().add_artist(legend_P2P3)
# Add legends to the plot

# Show the plot
plt.show()

# %%
# Load data
P2_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_JSZW.asc')
P2Ca121_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\P2_Ca121.asc')
P2Ca127_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_Ca127.asc')

# Load ticks Data
data_ticks_x_NiO = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_Ca127_ticks_NiO.tic')[:, 0]
#data_ticks_x_P2_Or = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\P2_JSZW_ticks_Or.tic')[:, 0]
data_ticks_x_P2_narrow = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_Ca127_ticks_P2_narrow.tic')[:, 0]
data_ticks_x_P2_broad_odd = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_Ca127_ticks_P2_broad_odd.tic')[:, 0]
data_ticks_x_P2_broad_even = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\RAL\\Rietveld Refinement\\ToS data\\P2_Ca127_ticks_P2_broad_even.tic')[:, 0]

x_P2, y_obs_P2, y_calc_P2 = P2_data[:, 0], P2_data[:, 1], P2_data[:, 2]
x_P2Ca121, y_obs_P2Ca121, y_calc_P2Ca121 = P2Ca121_data[:, 0], P2Ca121_data[:, 1], P2Ca121_data[:, 2]
x_P2Ca127, y_obs_P2Ca127, y_calc_P2Ca127 = P2Ca127_data[:, 0], P2Ca127_data[:, 1], P2Ca127_data[:, 2]

# Set offset values
offset_P2 = 5000
offset_P2Ca121 = 100000  # Adjust this value as needed
offset_P2Ca127 = 500000 # Adjust this value as needed

# Plotting
plt.figure(figsize=(7, 6))

# Plot 1: P2
plt.plot(x_P2, y_obs_P2 + offset_P2, label='Observed P2', linewidth = 0.5, color='black')
plt.plot(x_P2, y_calc_P2 + offset_P2, label='Calculated P2', linestyle='--', color='plum')

# Plot 2: P2_Ca121
plt.plot(x_P2Ca121, y_obs_P2Ca121 + offset_P2Ca121, label='Observed P2-Ca1/21', linewidth = 1, color='black')
plt.plot(x_P2Ca121, y_calc_P2Ca121 + offset_P2Ca121, label='Calculated P2-Ca1/21', linestyle='--', color='mediumturquoise')

# Plot 3: P2Ca127
plt.plot(x_P2Ca127, y_obs_P2Ca127 + offset_P2Ca127, label='Observed P2-Ca1/27', linewidth = 1, color='black')
plt.plot(x_P2Ca127, y_calc_P2Ca127 + offset_P2Ca127, label='Calculated P2-Ca1/27', linestyle='--', color='darkseagreen') 

# Plot ticks (P2)
plt.scatter(data_ticks_x_NiO, [75000 for x in data_ticks_x_NiO], marker='|', label='NiO')
#plt.scatter(data_ticks_x_P2_Or, [85000 for x in data_ticks_x_P2_Or], marker='|', label='P2_Or')
plt.scatter(data_ticks_x_P2_narrow, [85000 for x in data_ticks_x_P2_narrow], marker='|', label='P2', color = 'red') #Narrow')
plt.scatter(data_ticks_x_P2_broad_odd, [85000 for x in data_ticks_x_P2_broad_odd], marker='|', color ='red') # Broad Odd')
plt.scatter(data_ticks_x_P2_broad_even, [85000 for x in data_ticks_x_P2_broad_even], marker='|', color = 'red') # Broad Even') #label='P2',

# Set x-axis limit
plt.xlim(5, 60)  # Replace x_min and x_max with your desired limits
plt.ylim(0, 2000000) #100000,0 (4e4, 6e6) 

# Set y-axis to logarithmic scale
#plt.yscale('log')
#plt.yscale('sqrt')

# Adjust labels and legend
plt.xlabel(r'2$\theta$ / °', fontsize=16)
plt.ylabel('Intensity', fontsize=16)
plt.title('Ca doped P2 Series', fontsize=16)
plt.legend(bbox_to_anchor=(0.207, 1), loc='upper left', ncol=2)


# Show the plot
plt.show()

# %% [markdown]
# ## NFMO Ca-doped Series

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load data
P2_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\I11 Data\\October 2023\\P2_fit_volcano.asc')
P2_Ca_001_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\I11 Data\\October 2023\\P2_Ca0.01_fit_volcano.asc')
P2_Ca_002_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\I11 Data\\October 2023\\P2_Ca0.02_fit_volcano.asc')
P2_Ca_004_data = np.loadtxt('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\I11 Data\\October 2023\\P2_Ca0.04_fit_volcano.asc')

x_P2, y_obs_P2, y_calc_P2 = P2_data[:, 0], P2_data[:, 1], P2_data[:, 2]
x_P2_Ca_001, y_obs_P2_Ca_001, y_calc_P2_Ca_001 = P2_Ca_001_data[:, 0], P2_Ca_001_data[:, 1], P2_Ca_001_data[:, 2]
x_P2_Ca_002, y_obs_P2_Ca_002, y_calc_P2_Ca_002 = P2_Ca_002_data[:, 0], P2_Ca_002_data[:, 1], P2_Ca_002_data[:, 2]
x_P2_Ca_004, y_obs_P2_Ca_004, y_calc_P2_Ca_004 = P2_Ca_004_data[:, 0], P2_Ca_004_data[:, 1], P2_Ca_004_data[:, 2]
                            
# Set offset values
#offset_P2 = 0
#offset_P2_Ca_001 = 500000  # Adjust this value as needed
#offset_P2_Ca_002 = 2000000  # Adjust this value as needed
#offset_P2_Ca_004 = 5000000

# Set offset values non logs
offset_P2 = 0
offset_P2_Ca_001 = 1000000  # Adjust this value as needed
offset_P2_Ca_002 = 2000000  # Adjust this value as needed
offset_P2_Ca_004 = 3000000

# Plotting
plt.figure(figsize=(10, 6))

# Plot 1: P2
#plt.plot(x_P2, y_obs_P2 + offset_P2, label='Observed P2', color='blue')
#plt.plot(x_P2, y_calc_P2 + offset_P2, label='Calculated P2', linestyle='--', color='red')

# Plot 2: P2_Ca_0.01
#plt.plot(x_P2_Ca_001, y_obs_P2_Ca_001 + offset_P2_Ca_001, label='Observed P2_Ca_0.01', color='green')
#plt.plot(x_P2_Ca_001, y_calc_P2_Ca_001 + offset_P2_Ca_001, label='Calculated P2_Ca_0.01', linestyle='--', color='orange')

# Plot 3: P2_Ca_0.02
#plt.plot(x_P2_Ca_002, y_obs_P2_Ca_002 + offset_P2_Ca_002, label='Observed P2_Ca_0.02', color='purple')
#plt.plot(x_P2_Ca_002, y_calc_P2_Ca_002 + offset_P2_Ca_002, label='Calculated P2_Ca_0.02', linestyle='--', color='brown')

# Plot 4: P2_Ca_0.04
#plt.plot(x_P2_Ca_004, y_obs_P2_Ca_004 + offset_P2_Ca_004, label='Observed P2_Ca_0.04', color='black')
#plt.plot(x_P2_Ca_004, y_calc_P2_Ca_004 + offset_P2_Ca_004, label='Calculated P2_Ca_0.04', linestyle='--', color='pink')


#######################
#Plot all same colours
# Plot 1: P2
plt.plot(x_P2, y_obs_P2 + offset_P2, label='Observed P2', color='black')
plt.plot(x_P2, y_calc_P2 + offset_P2, label='Calculated P2', linestyle='--', color='red')

# Plot 2: P2_Ca_0.01
plt.plot(x_P2_Ca_001, y_obs_P2_Ca_001 + offset_P2_Ca_001, label='Observed P2_Ca_0.01', color='black')
plt.plot(x_P2_Ca_001, y_calc_P2_Ca_001 + offset_P2_Ca_001, label='Calculated P2_Ca_0.01', linestyle='--', color='red')

# Plot 3: P2_Ca_0.02
plt.plot(x_P2_Ca_002, y_obs_P2_Ca_002 + offset_P2_Ca_002, label='Observed P2_Ca_0.02', color='black')
plt.plot(x_P2_Ca_002, y_calc_P2_Ca_002 + offset_P2_Ca_002, label='Calculated P2_Ca_0.02', linestyle='--', color='red')


# Plot 4: P2_Ca_0.04
plt.plot(x_P2_Ca_004, y_obs_P2_Ca_004 + offset_P2_Ca_004, label='Observed P2_Ca_0.04', color='black')
plt.plot(x_P2_Ca_004, y_calc_P2_Ca_004 + offset_P2_Ca_004, label='Calculated P2_Ca_0.04', linestyle='--', color='red')
                            


# Set x-axis limit
plt.xlim(5, 40)  # Replace x_min and x_max with your desired limits
#plot with log:
#plt.ylim(20000,9000000)
#plot without log:
#plt.ylim(0,10000)


# Set y-axis to logarithmic scale
#plt.yscale('log')

# Adjust labels and legend
plt.xlabel(r'2$\theta$ / °', fontsize=16)
#plt.ylabel('Intensity (log scale)', fontsize=16)
plt.ylabel('Intensity', fontsize=16)
plt.title('Ca doped P2-NFMO Series', fontsize=16)
plt.legend(bbox_to_anchor=(1.1, 1.05), loc='upper left')

# Show the plot
#plt.show()
plt.savefig('C:\\Users\\chem-exet5737\\OneDrive - Nexus365\\I11 Data\\October 2023\\Python figures\\test_NFMMO_Stacked_XRD_plot.png', dpi=300, bbox_inches="tight")

# %% [markdown]
# Muon Samples - SXRD with Rietveld Refinement

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load data
P2P3_data = np.loadtxt(r'C:\Users\chem-exet5737\OneDrive - Nexus365\I11 Data\Jan 2024\P2P3.asc')
P2P3Ca272_data = np.loadtxt(r'C:\Users\chem-exet5737\OneDrive - Nexus365\I11 Data\Jan 2024\P2P3Ca272.asc')
P2P3Ca372_data = np.loadtxt(r'C:\Users\chem-exet5737\OneDrive - Nexus365\I11 Data\Jan 2024\P2P3Ca372.asc')

# Load ticks Data
data_ticks_x_NiO = np.loadtxt(r'C:\Users\chem-exet5737\OneDrive - Nexus365\I11 Data\Jan 2024\NiO_Ca272_ticks.asc')[:, 0]
data_ticks_x_P2 = np.loadtxt(r'C:\Users\chem-exet5737\OneDrive - Nexus365\I11 Data\Jan 2024\P2_Ca272_ticks.asc')[:, 0]
data_ticks_x_P3 = np.loadtxt(r'C:\Users\chem-exet5737\OneDrive - Nexus365\I11 Data\Jan 2024\P3_Ca272_ticks.asc')[:, 0]

x_P2P3, y_calc_P2P3, y_obs_P2P3 = P2P3_data[:, 0], P2P3_data[:, 1], P2P3_data[:, 2]
x_P2P3Ca272, y_calc_P2P3Ca272, y_obs_P2P3Ca272 = P2P3Ca272_data[:, 0], P2P3Ca272_data[:, 1], P2P3Ca272_data[:, 2]
x_P2P3Ca372, y_calc_P2P3Ca372, y_obs_P2P3Ca372 = P2P3Ca372_data[:, 0], P2P3Ca372_data[:, 1], P2P3Ca372_data[:, 2]

# Set offset values
offset_P2P3 = 300 #80000
offset_P2P3Ca272 = 1400 #500000  # Adjust this value as needed
offset_P2P3Ca372 = 2600 #1200000 # Adjust this value as needed

# Plotting
plt.figure(figsize=(9, 6))

# Plot 1: P2P3
plt.plot(x_P2P3, np.sqrt(y_obs_P2P3) + offset_P2P3, label='Observed P2P3', linewidth = 0.5, color='black')
plt.plot(x_P2P3, np.sqrt(y_calc_P2P3) + offset_P2P3, label='Calculated P2P3', linestyle='--', color='plum')
#legend1 = plt.legend(bbox_to_anchor=(0.75, 1), loc='upper left')

# Plot 2: P2P3Ca272
plt.plot(x_P2P3Ca272, np.sqrt(y_obs_P2P3Ca272) + offset_P2P3Ca272, label='Observed P2P3Ca2/72', linewidth = 1, color='black')
plt.plot(x_P2P3Ca272, np.sqrt(y_calc_P2P3Ca272) + offset_P2P3Ca272, label='Calculated P2P3Ca2/72', linestyle='--', color='mediumturquoise')
#legend2 = plt.legend(bbox_to_anchor=(0.5, 1), loc='upper left')

# Plot 3: P2P3Ca372
plt.plot(x_P2P3Ca372, np.sqrt(y_obs_P2P3Ca372) + offset_P2P3Ca372, label='Observed P2P3Ca3/72', linewidth = 1, color='black')
plt.plot(x_P2P3Ca372, np.sqrt(y_calc_P2P3Ca372) + offset_P2P3Ca372, label='Calculated P2P3Ca3/72', linestyle='--', color='darkseagreen') 
#legend3 = plt.legend(bbox_to_anchor=(0.25, 1), loc='upper left')

# Plot ticks 
plt.scatter(data_ticks_x_NiO, [100 for x in data_ticks_x_NiO], marker='|', label='NiO', color='blue')
plt.scatter(data_ticks_x_P2, [200 for x in data_ticks_x_P2], marker='|', label='P2', color = 'red')
plt.scatter(data_ticks_x_P3, [300 for x in data_ticks_x_P3], marker='|', label='P3', color ='green')


# Set x-axis limit
plt.xlim(5, 59.6)  # Replace x_min and x_max with your desired limits
plt.ylim(0, 4000) #100000,0 (4e4, 6e6) 

# Set y-axis to logarithmic scale
#plt.yscale('log')
#plt.yscale('sqrt')

# Adjust labels and legend
plt.xlabel(r'2$\theta$ / °', fontsize=16)
plt.ylabel('Intensity sqrt(y)', fontsize=16)
plt.title('Ca doped P2P3 Series', fontsize=16)
plt.xticks(fontsize=20)
#plt.yticks(fontsize=20)
#plt.legend(bbox_to_anchor=(0.4, 1), loc='upper left', ncol=3)

legend_P2P3 = plt.legend(['Observed P2P3', 'Calculated P2P3'], loc='upper left', bbox_to_anchor=(0.77, 0.35), labelcolor=['black', 'plum'], handlelength=0)
plt.gca().add_artist(legend_P2P3)
legend_P2P3Ca272 = plt.legend(['Observed P2P3Ca2/72', 'Calculated P2P3Ca2/72'], loc='upper left', bbox_to_anchor=(0.7, 0.65), labelcolor=['black', 'mediumturquoise'], handlelength=0)
plt.gca().add_artist(legend_P2P3Ca272)
legend_P2P3Ca372 = plt.legend(['Observed P2P3Ca3/72', 'Calculated P2P3Ca3/72'], loc='upper left', bbox_to_anchor=(0.7, 1), labelcolor=['black', 'darkseagreen'], handlelength=0)
plt.gca().add_artist(legend_P2P3Ca372)
legend_ticks = plt.legend(['P3', 'P2', 'NiO'], loc='upper left', bbox_to_anchor=(1, 0.155), labelcolor=['green','red', 'blue'], handlelength=0)
plt.gca().add_artist(legend_P2P3)
# Add legends to the plot



"""
proxy_P2P3 = plt.Line2D([0], [0], linestyle='None', marker='-', markersize=10, color='black')
proxy_P2P3Ca272 = plt.Line2D([0], [0], linestyle='None', marker='-', markersize=10, color='mediumturquoise')
proxy_P2P3Ca372 = plt.Line2D([0], [0], linestyle='None', marker='-', markersize=10, color='darkseagreen')

# Manually create legend for each group of data with proxy artists
legend_P2P3 = plt.legend([proxy_P2P3], ['P2P3'], loc='upper left', bbox_to_anchor=(0.75, 1))
legend_P2P3Ca272 = plt.legend([proxy_P2P3Ca272], ['P2P3Ca2/72'], loc='upper left', bbox_to_anchor=(0.68, 0.6))
legend_P2P3Ca372 = plt.legend([proxy_P2P3Ca372], ['P2P3Ca3/72'], loc='upper left', bbox_to_anchor=(0.68, 0.3))

# Add legends to the plot
plt.gca().add_artist(legend_P2P3)
plt.gca().add_artist(legend_P2P3Ca272)
plt.gca().add_artist(legend_P2P3Ca372)
"""
# Show the plot
plt.show()

# %%
from XRD_plotting.preprocessing import PreProcessingXRD
dataset_name = "O3Redo_Muon.asc"
file_path = rf"C:\Users\chem-exet5737\OneDrive - Nexus365\I11 Data\March 2024\{dataset_name}"
#df= PreProcessingXRD(dataset_name, file_path).process_asc_df()
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20808\1275759376.py in <module>
#       3 file_path = rf"C:\Users\chem-exet5737\OneDrive - Nexus365\I11 Data\March 2024\{dataset_name}"
#       4 #df= PreProcessingXRD(dataset_name, file_path).process_asc_df()
# ----> 5 print(df)
#
# NameError: name 'df' is not defined
