# %% [markdown]
# ## Rietveld Refinement - Plotting XRD Patterns

# %% [markdown]
# ##### First run the code line below:

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ##### To generate a figure of just 1 dataset of raw .xye data:

# %%
from battery_characterisation_tool.xrd_plotting.xrd_plot import XRDPlotter 

legend_labels = ["P3O3Ca172"]
plot_title = "XRD Pattern for P3O3 Ca 172 with Intensity sqrt"
file_path = r".xye"
xlim = (3, 80)
ylim = (100, 1500) #for sqrt ~(100, 1500) for normal intensity ~(0, 1e6 or more)
fontsize = 16
transformation_type = "sqrt" #You must enter here either "sqrt" for square root of intensity, "log" for log of intensity, or leave it as "" for normal intensity.


plot = XRDPlotter(file_path=file_path, 
                            plot_title = plot_title,  
                            legend_labels=legend_labels,
                            xlim=xlim,
                            ylim=ylim,
                            fontsize=fontsize,
                            transformation_type=transformation_type)
plot.raw_xye_plot()

# %%
from battery_characterisation_tool.xrd_plotting.xrd_plot import XRDPlotter 

legend_labels = ["P3O3Ca172"]
plot_title = "XRD Pattern for P3O3 Ca 172"
file_path = r".xye"
xlim = (3, 80)
ylim = (0, 2e6) #for sqrt ~(100, 1500) for normal intensity ~(0, 2e6 or more)
fontsize = 20
zoom_x_limit = 28 
zoom_width = 10

plot = XRDPlotter(file_path=file_path, 
                            plot_title = plot_title,  
                            legend_labels=legend_labels,
                            xlim=xlim,
                            ylim=ylim,
                            fontsize=fontsize,
                            zoom_x_limit=zoom_x_limit,
                            zoom_width=zoom_width)
plot.raw_xye_plot_zoom()

# %% [markdown]
# #### To generate a figure of multiple xrd plots stacked in one figure:

# %%
from battery_characterisation_tool.xrd_plotting.xrd_plot import XRDPlotter 

folder_path = rf"\xye files"
legend_labels = ["P2P3Ca172", "P2P3Ca472", "P3O3Ca172", "P3O3Ca472"]
plot_title = "XRD Patterns for biphasic materials"
xlim = (3, 80)
ylim = (8, 30) #for sqrt ~(100, 1500) for normal intensity ~(0, 1e6 or more) or for log intensity ~(8, 30)
fontsize =16
#offsets = [0, 2e5, 4e5, 6e5] #for normal intensity values
#offsets = [0, 500, 1000, 1500] #for sqrt values
offsets = [0, 5, 10, 15] #for log values
transformation_type = "log" #You must enter here either "sqrt" for square root of intensity, "log" for log of intensity, or leave it as "" for normal intensity.

plot = XRDPlotter(folder_path=folder_path, 
                            plot_title = plot_title,  
                            legend_labels=legend_labels,
                            xlim=xlim,
                            ylim=ylim,
                            fontsize=fontsize,
                            offsets=offsets,
                            transformation_type=transformation_type)
plot.plot_stacked_datasets()

# %% [markdown]
# ### Plotting a single refinement

# %%
import numpy as np
file_path = rf".asc"
df = np.loadtxt(file_path, delimiter='', encoding= 'unicode_escape')
print(df)

# %%
from battery_characterisation_tool.xrd_plotting.xrd_plot import XRDPlotter 

file_path = rf".asc"
legend_labels = ["Observed Pattern of P3O3Ca172", "Calculated Pattern of P3O3Ca172"]
plot_title = "Rietveld Refinement"
xlim = (3, 30)
ylim = (100, 1000) #for sqrt ~(100, 1500) for normal intensity ~(0, 1e6 or more) or for log intensity ~(8, 30)
fontsize =16
transformation_type = "sqrt"

plot = XRDPlotter(file_path=file_path, 
                            plot_title = plot_title,  
                            legend_labels=legend_labels,
                            xlim=xlim,
                            ylim=ylim,
                            fontsize=fontsize,
                            transformation_type=transformation_type)
plot.rietveld_refinement_plot()

# %% [markdown]
# ### Rietveld refinement with ticks

# %%
from battery_characterisation_tool.xrd_plotting.xrd_plot import XRDPlotter 
#update this to check it works with folder path & check class code function works for this - need to include offset
folder_path = rf""
legend_labels = ["Observed Pattern of P3O3Ca172", "Calculated Pattern of P3O3Ca172"]
plot_title = "Rietveld Refinement of P3O3Ca472"
xlim = (3, 80)
ylim = (-1000, 1e6) #for sqrt ~(100, 1500) for normal intensity ~(0, 1e6 or more) or for log intensity ~(8, 30)
fontsize = 16
#transformation_type = "sqrt"

plot = XRDPlotter(folder_path=folder_path, 
                            plot_title = plot_title,  
                            legend_labels=legend_labels,
                            xlim=xlim,
                            ylim=ylim,
                            fontsize=fontsize,
                            transformation_type=transformation_type)
plot.rietveld_refinement_with_ticks()

# %% [markdown]
# #### Plotting stacked refinements

# %%
from battery_characterisation_tool.xrd_plotting.xrd_plot import XRDPlotter 

folder_path = rf""
legend_labels = ["P3O3Ca172", "P3O3Ca272", "P3O3Ca372", "P3O3Ca472"]
plot_title = "XRD Patterns for biphasic materials"
xlim = (3, 50)
ylim = (100, 2750) #for sqrt ~(100, 1500) for normal intensity ~(0, 1e6 or more) or for log intensity ~(8, 30)
fontsize =16
#offsets = [0, 2e5, 4e5, 6e5] #for normal intensity values
offsets = [0, 500, 1000, 1500] #for sqrt values
#offsets = [0, 5, 10, 15] #for log values
transformation_type = "sqrt" #You must enter here either "sqrt" for square root of intensity, "log" for log of intensity, or leave it as "" for normal intensity.

plot = XRDPlotter(folder_path=folder_path, 
                            plot_title = plot_title,  
                            legend_labels=legend_labels,
                            xlim=xlim,
                            ylim=ylim,
                            fontsize=fontsize,
                            offsets=offsets,
                            transformation_type=transformation_type)
plot.rietveld_stacked()

# %% [markdown]
# ### Plotting a Rietveld refinement with the difference

# %%
from battery_characterisation_tool.xrd_plotting.xrd_plot import XRDPlotter 

file_path = rf".asc"
legend_labels = ["Observed Pattern of P3O3Ca172", "Calculated Pattern of P3O3Ca172"]
plot_title = "Rietveld Refinement"
xlim = (3, 30)
ylim = (100, 1500) #for sqrt ~(100, 1500) for normal intensity ~(0, 1e6 or more) or for log intensity ~(8, 30)
fontsize = 16
transformation_type = "sqrt"

plot = XRDPlotter(file_path=file_path, 
                            plot_title = plot_title,  
                            legend_labels=legend_labels,
                            xlim=xlim,
                            ylim=ylim,
                            fontsize=fontsize,
                            transformation_type=transformation_type)
plot.rietveld_difference_plot()

# %%
data = np.loadtxt('')
x = data[:, 0]
y_obs = data[:, 1]
y_calc = data[:, 2]

plt.rcParams['font.family']='serif'

fig, ax = plt.subplots(2, 1, figsize=(16, 10))

for i in range(2):
    ax[i].scatter(x, y_obs, s=5, color='black', label='Observed')
    ax[i].plot(x, y_calc, linewidth=1.5, color='red', label='Calculated')
    ax[i].set_xlabel(r'2$\theta$ / °', fontsize = 16)
    ax[i].yaxis.set_ticklabels([])
    ax[i].yaxis.set_ticks([])
ax[0].set_xlim(7, 65)
ax[1].set_xlim(16, 28)
ax[1].set_ylim(-100,500000)
#ax[0, 1].set_xlim(20, 35)
#ax[1, 1].set_xlim(35, 50)
#ax[0].set_facecolor('cyan', extent=(10, 20, 100, 300))

rect = patches.Rectangle((16, -100000), 12, 3000000, linewidth=2, edgecolor='blue', facecolor='cyan', alpha=0.1)
ax[0].add_patch(rect)
rect = patches.Rectangle((16, -2000), 12, 3000000, linewidth=2, edgecolor='blue', facecolor='cyan', alpha=0.1)
ax[1].add_patch(rect)
plt.subplots_adjust(hspace=0.3)      #This adjusts the space between the two plots
ax[0].set_ylabel('Intensity', fontsize=16)
ax[1].set_ylabel('Intensity', fontsize=16)

ax[0].legend(fontsize =16) #(bbox_to_anchor=(1, 1.05), loc='upper left')
plt.tight_layout()

#plt.savefig('.png', dpi=300)

# %%
data = np.loadtxt('.asc')
x = data[:, 0]
y_obs = data[:, 1]
y_calc = data[:, 2]

plt.rcParams['font.family']='serif'

fig, ax = plt.subplots(2, 1, figsize=(16, 10))


for i in range(2):
    ax[i].scatter(x, y_obs, s=5, color='black', label='Observed')
    ax[i].plot(x, y_calc, linewidth=1.5, color='red', label='Calculated')
    ax[i].set_xlabel(r'2$\theta$ / °', fontsize = 16)
    ax[i].yaxis.set_ticklabels([])
    ax[i].yaxis.set_ticks([])
ax[0].set_xlim(7, 65)
ax[1].set_xlim(16, 28)
ax[1].set_ylim(-100,650000)
#ax[0, 1].set_xlim(20, 35)
#ax[1, 1].set_xlim(35, 50)
#ax[0].set_facecolor('cyan', extent=(10, 20, 100, 300))

#rect = patches.Rectangle((16, -150000), 12, 10000000, linewidth=2, edgecolor='blue', facecolor='cyan', alpha=0.1)
#ax[0].add_patch(rect)
#rect = patches.Rectangle((16, -2000), 12, 3000000, linewidth=2, edgecolor='blue', facecolor='cyan', alpha=0.1)
#ax[1].add_patch(rect)
plt.subplots_adjust(hspace=0.3)      #This adjusts the space between the two plots
ax[0].set_ylabel('Intensity', fontsize=16)
ax[1].set_ylabel('Intensity', fontsize=16)

ax[0].legend(fontsize =16) #(bbox_to_anchor=(1, 1.05), loc='upper left')
plt.tight_layout()
#plt.savefig('.png', dpi=300)

# %%
data = np.loadtxt('.asc')

x = data[:, 0]
y_obs = data[:, 1]
y_calc = data[:, 2]

plt.rcParams['font.family']='serif'

fig, ax = plt.subplots(2, 1, figsize=(16, 10))


for i in range(2):
    ax[i].scatter(x, y_obs, s=5, color='black', label='Observed')
    ax[i].plot(x, y_calc, linewidth=1.5, color='red', label='Calculated')
    ax[i].set_xlabel(r'2$\theta$ / °', fontsize = 16)
    ax[i].yaxis.set_ticklabels([])
    ax[i].yaxis.set_ticks([])
ax[0].set_xlim(7, 65)
ax[1].set_xlim(16, 28)
ax[1].set_ylim(-100,800000)
#ax[0, 1].set_xlim(20, 35)
#ax[1, 1].set_xlim(35, 50)
#ax[0].set_facecolor('cyan', extent=(10, 20, 100, 300))

#rect = patches.Rectangle((16, -250000), 12, 10000000, linewidth=2, edgecolor='blue', facecolor='cyan', alpha=0.1)
#ax[0].add_patch(rect)
#rect = patches.Rectangle((16, -2000), 12, 3000000, linewidth=2, edgecolor='blue', facecolor='cyan', alpha=0.1)
#ax[1].add_patch(rect)
plt.subplots_adjust(hspace=0.3)      #This adjusts the space between the two plots
ax[0].set_ylabel('Intensity', fontsize=16)
ax[1].set_ylabel('Intensity', fontsize=16)

ax[0].legend(fontsize =16) #(bbox_to_anchor=(1, 1.05), loc='upper left')
plt.tight_layout()
#plt.savefig('.png', dpi=300)

# %% [markdown]
# ### To load 2 sets of XRD Data/Rietveld analyses use the below code:

# %% [markdown]
# ##### You will need to change the x_P2 down to y_calc_P2Ca127 column titles to your own data titles and then below where mentioned in the for loop.

# %%
P2_data = np.loadtxt('.asc')
P2Ca127_data = np.loadtxt('.asc')
x_P2 = P2_data[:, 0]
y_obs_P2 = P2_data[:, 1]
y_calc_P2 = P2_data[:, 2]
x_P2Ca127 = P2Ca127_data[:, 0]
y_obs_P2Ca127 = P2Ca127_data[:, 1]
y_calc_P2Ca127 = P2Ca127_data[:, 2]

plt.rcParams['font.family']='serif'

fig, ax = plt.subplots(2, 2, figsize=(16, 10))

for i in range(2):
    ax[i,0].scatter(x_P2, y_obs_P2, s=5, color='black', label='Observed')
    ax[i,0].plot(x_P2, y_calc_P2, linewidth=1.5, color='red', label='Calculated')
    #P2Ca127
    ax[i,1].scatter(x_P2Ca127, y_obs_P2Ca127, s=5, color='black', label='Observed')
    ax[i,1].plot(x_P2Ca127, y_calc_P2Ca127, linewidth=1.5, color='red', label='Calculated')
    ##
    ax[i,0].set_xlabel(r'2$\theta$ / °', fontsize = 16)
    ax[i,0].yaxis.set_ticklabels([])
    ax[i,0].yaxis.set_ticks([])
    ax[i,1].set_xlabel(r'2$\theta$ / °', fontsize = 16)
    ax[i,1].yaxis.set_ticklabels([])
    ax[i,1].yaxis.set_ticks([])
ax[0,0].set_xlim(7, 65)
ax[1,0].set_xlim(16, 28)
ax[0,0].set_ylim(-100,4400000)
#second
ax[0,1].set_xlim(7, 65)
ax[1,1].set_xlim(16, 28)
ax[0,1].set_ylim(-100,4400000)
ax[1,1].set_ylim(-100,800000)
ax[1,0].set_ylim(-100,800000)
#ax[0, 1].set_xlim(20, 35)
#ax[1, 1].set_xlim(35, 50)
#ax[0].set_facecolor('cyan', extent=(10, 20, 100, 300))

rect = patches.Rectangle((16, -250000), 12, 10000000, linewidth=2, edgecolor='mediumorchid', facecolor='palevioletred', alpha=0.1)
ax[0,0].add_patch(rect)
rect = patches.Rectangle((16, -250000), 12, 10000000, linewidth=2, edgecolor='blue', facecolor='cyan', alpha=0.1)
ax[0,1].add_patch(rect)
rect = patches.Rectangle((16, -250000), 12, 8000000, linewidth=2, edgecolor='mediumorchid', facecolor='palevioletred', alpha=0.1)
ax[1,0].add_patch(rect)
rect = patches.Rectangle((16, -250000), 12, 8000000, linewidth=2, edgecolor='blue', facecolor='cyan', alpha=0.1)
ax[1,1].add_patch(rect)
plt.subplots_adjust(hspace=0.3)      #This adjusts the space between the two plots
ax[0,1].set_ylabel('Intensity', fontsize=16)
ax[1,1].set_ylabel('Intensity', fontsize=16)
ax[0,0].set_ylabel('Intensity', fontsize=16)
ax[1,0].set_ylabel('Intensity', fontsize=16)

ax[0,1].legend(fontsize =16) #(bbox_to_anchor=(1, 1.05), loc='upper left')
ax[0,0].legend(fontsize =16) #(bbox_to_anchor=(1, 1.05), loc='upper left')
#ax[0,0].set_title("XRPD for Pristine P2", fontsize = 16)
#ax[0,1].set_title(f"XRPD for P2-Na/N{SUBSCRIPT 16/27}Ca/N{SUBSCRIPT 1/27}Ni/N{SUBSCRIPT 1/3}Mn/N{SUBSCRIPT2/3}O/N{SUBSCRIPT 2}" , fontsize = 16)
#ax[1,0].set_title("C", fontsize = 16)
#ax[1,1].set_title("D", fontsize = 16)
plt.tight_layout()
#plt.savefig('.png', dpi=300)

# %% [markdown]
# ### Plotting Tick Marks with Refinements

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
data = np.loadtxt('.asc')

x = data[:, 0]
y_obs = data[:, 1]
y_calc = data[:, 2]

plt.rcParams['font.family']='serif'


data_ticks_x_NiO = np.loadtxt('.tic')[:, 0]
#data_ticks_x_P2_Or = np.loadtxt('.tic')[:, 0]
data_ticks_x_P2_narrow = np.loadtxt('.tic')[:, 0]
data_ticks_x_P2_broad_odd = np.loadtxt('.tic')[:, 0]
data_ticks_x_P2_broad_even = np.loadtxt('.tic')[:, 0]


fig, ax = plt.subplots(2, 1, figsize=(10, 10))



for i in range(2):
    ax[i].scatter(x, y_obs, s=0.2, color='black', label='Observed')
    ax[i].plot(x, y_calc, linewidth=0.5, color='red', label='Calculated')
    ax[i].set_xlabel(r'2$\theta$ / °', fontsize = 16)
    ax[i].yaxis.set_ticklabels([])
    ax[i].yaxis.set_ticks([])
ax[0].set_xlim(5, 65)
#ax[1].set_xlim(16.5, 26.5)
ax[0].set_ylim(-600000,2500000) #(-600000,4400000)
#ax[1].set_ylim(-200000,800000)
#ax[0, 1].set_xlim(20, 35)
#ax[1, 1].set_xlim(35, 50)
#ax[0].set_facecolor('cyan', extent=(10, 20, 100, 300))

ax[0].scatter(data_ticks_x_NiO, [-100000 for x in data_ticks_x_NiO], marker='|', label='NiO')
#ax[0].scatter(data_ticks_x_P2_Or, [-3300 for x in data_ticks_x_P2_Or], marker='|', label='P2 Or')
ax[0].scatter(data_ticks_x_P2_narrow, [-200000 for x in data_ticks_x_P2_narrow], marker='|', label='P2') # Narrow')
ax[0].scatter(data_ticks_x_P2_broad_odd, [-400000 for x in data_ticks_x_P2_broad_odd], marker='|', label='P2') # Broad Odd')
ax[0].scatter(data_ticks_x_P2_broad_even, [-500000 for x in data_ticks_x_P2_broad_even], marker='|', label='P2') # Broad Even')

#ax[1].scatter(data_ticks_x_NiO, [-1000 for x in data_ticks_x_NiO], marker='|', label='NiO')
  #ax[1].scatter(data_ticks_x_P2_Or, [-3300 for x in data_ticks_x_P2_Or], marker='|', label='P2_Or')
#ax[1].scatter(data_ticks_x_P2_narrow, [-50000 for x in data_ticks_x_P2_narrow], marker='|', label='P2') # Narrow')
#ax[1].scatter(data_ticks_x_P2_broad_odd, [-100000 for x in data_ticks_x_P2_broad_odd], marker='|', label='P2') # Broad Odd')
#ax[1].scatter(data_ticks_x_P2_broad_even, [-150000 for x in data_ticks_x_P2_broad_even], marker='|', label='P2') # Broad Even')

#rect = patches.Rectangle((16, -250000), 12, 10000000, linewidth=2, edgecolor='mediumorchid', facecolor='palevioletred', alpha=0.1)
#ax[0,0].add_patch(rect)
#rect = patches.Rectangle((16, -250000), 12, 10000000, linewidth=2, edgecolor='blue', facecolor='cyan', alpha=0.1)
#ax[0,1].add_patch(rect)
#rect = patches.Rectangle((16, -250000), 12, 8000000, linewidth=2, edgecolor='mediumorchid', facecolor='palevioletred', alpha=0.1)
#ax[1,0].add_patch(rect)
#rect = patches.Rectangle((16, -250000), 12, 8000000, linewidth=2, edgecolor='blue', facecolor='cyan', alpha=0.1)



#rect = patches.Rectangle((16, -600000), 12, 5800000, linewidth=2, edgecolor='mediumorchid', facecolor='palevioletred', alpha=0.1)
#ax[0].add_patch(rect)
#rect = patches.Rectangle((16, -200000), 12, 3000000, linewidth=2, edgecolor='mediumorchid', facecolor='palevioletred', alpha=0.1)
#ax[1].add_patch(rect)
plt.subplots_adjust(hspace=0.3)
ax[0].set_ylabel('Intensity', fontsize=16)
#ax[1].set_ylabel('Intensity', fontsize=16)
#ax[0].yaxis.set_label_coords(-0.02, -0.15)

ax[0].legend(bbox_to_anchor=(1, 1.05), loc='upper left', fontsize =14)
#ax[1].legend(bbox_to_anchor=(1, 1.05), loc='upper left', fontsize =14)
plt.tight_layout()
plt.savefig('.png', dpi=300)

# %%
data = np.loadtxt('.asc')

x = data[:, 0]
y_obs = data[:, 1]
y_calc = data[:, 2]

plt.rcParams['font.family']='serif'


data_ticks_x_NiO = np.loadtxt('_NiO.tic')[:, 0]
#data_ticks_x_P2_Or = np.loadtxt('.tic')[:, 0]
data_ticks_x_P2_narrow = np.loadtxt('P_narrow.tic')[:, 0]
data_ticks_x_P2_broad_odd = np.loadtxt('.tic')[:, 0]
data_ticks_x_P2_broad_even = np.loadtxt('.tic')[:, 0]


fig, ax = plt.subplots(2, 1, figsize=(12, 7.5))


for i in range(2):
    ax[i].scatter(x, y_obs, s=0.2, color='black', label='Observed')
    ax[i].plot(x, y_calc, linewidth=0.5, color='red', label='Calculated')
    ax[i].set_xlabel(r'2$\theta$ / °', fontsize = 16)
    ax[i].yaxis.set_ticklabels([])
    ax[i].yaxis.set_ticks([])
ax[0].set_xlim(5, 65)
ax[1].set_xlim(16.5, 26.5)
#ax[0].set_ylim(-400000,4400000)
#ax[1].set_ylim(-200000,800000)
ax[0].set_ylim(-600000,4400000)
ax[1].set_ylim(-200000,800000)
#ax[0, 1].set_xlim(20, 35)
#ax[1, 1].set_xlim(35, 50)
#ax[0].set_facecolor('cyan', extent=(10, 20, 100, 300))

ax[0].scatter(data_ticks_x_NiO, [-100000 for x in data_ticks_x_NiO], marker='|', label='NiO')
#ax[0].scatter(data_ticks_x_P2_Or, [-3300 for x in data_ticks_x_P2_Or], marker='|', label='P2 Or')
ax[0].scatter(data_ticks_x_P2_narrow, [-200000 for x in data_ticks_x_P2_narrow], marker='|', label='P2') #Narrow
ax[0].scatter(data_ticks_x_P2_broad_odd, [-400000 for x in data_ticks_x_P2_broad_odd], marker='|', label='P2') #Broad Odd
ax[0].scatter(data_ticks_x_P2_broad_even, [-500000 for x in data_ticks_x_P2_broad_even], marker='|', label='P2') # Broad Even

ax[1].scatter(data_ticks_x_NiO, [-1000 for x in data_ticks_x_NiO], marker='|', label='NiO')
#ax[1].scatter(data_ticks_x_P2_Or, [-3300 for x in data_ticks_x_P2_Or], marker='|', label='P2_Or')
ax[1].scatter(data_ticks_x_P2_narrow, [-50000 for x in data_ticks_x_P2_narrow], marker='|', label='P2') #Narrow')
ax[1].scatter(data_ticks_x_P2_broad_odd, [-100000 for x in data_ticks_x_P2_broad_odd], marker='|', label='P2') # Broad Odd')
ax[1].scatter(data_ticks_x_P2_broad_even, [-150000 for x in data_ticks_x_P2_broad_even], marker='|', label='P2') # Broad Even')

#rect = patches.Rectangle((16, -250000), 12, 10000000, linewidth=2, edgecolor='mediumorchid', facecolor='palevioletred', alpha=0.1)
#ax[0,0].add_patch(rect)
#rect = patches.Rectangle((16, -250000), 12, 10000000, linewidth=2, edgecolor='blue', facecolor='cyan', alpha=0.1)
#ax[0,1].add_patch(rect)
#rect = patches.Rectangle((16, -250000), 12, 8000000, linewidth=2, edgecolor='mediumorchid', facecolor='palevioletred', alpha=0.1)
#ax[1,0].add_patch(rect)
#rect = patches.Rectangle((16, -250000), 12, 8000000, linewidth=2, edgecolor='blue', facecolor='cyan', alpha=0.1)



rect = patches.Rectangle((16, -600000), 12, 5800000, linewidth=2, edgecolor='blue', facecolor='cyan', alpha=0.1)
ax[0].add_patch(rect)
rect = patches.Rectangle((16, -200000), 12, 3000000, linewidth=2, edgecolor='blue', facecolor='cyan', alpha=0.1)
ax[1].add_patch(rect)
plt.subplots_adjust(hspace=0.3)
ax[0].set_ylabel('Intensity', fontsize=16)
ax[1].set_ylabel('Intensity', fontsize=16)
#ax[0].yaxis.set_label_coords(-0.02, -0.15)

ax[0].legend(bbox_to_anchor=(1, 1.05), loc='upper left', fontsize =14)
ax[1].legend(bbox_to_anchor=(1, 1.05), loc='upper left', fontsize =14)
plt.tight_layout()
plt.savefig('_with_ticks.png', dpi=300)

# %% [markdown]
# ### Plotting XRD data (not the refinements):

# %%
data = np.loadtxt(r'.dat')
x = data[:, 0]
y_obs = data[:, 1]
y_calc = data[:, 2]

plt.rcParams['font.family']='serif'

fig, ax = plt.subplots(2, 1, figsize=(16, 10))

for i in range(2):
    #ax[i].scatter(x, y_obs, s=0.2, color='black', label='Observed')
    ax[i].plot(x, y_obs, linewidth=0.5, color='black', label='Observed')
    ax[i].set_xlabel(r'2$\theta$ / °')
    ax[i].yaxis.set_ticklabels([])
    ax[i].yaxis.set_ticks([])
ax[0].set_xlim(0, 70)
ax[1].set_xlim(16, 27)
ax[1].set_ylim(-100,700000)
#ax[0, 1].set_xlim(20, 35)
#ax[1, 1].set_xlim(35, 50)
#ax[0].set_facecolor('cyan', extent=(10, 20, 100, 300))

rect = patches.Rectangle((16, -2000000), 11, 6000000, linewidth=2, edgecolor='blue', facecolor='cyan', alpha=0.1)
ax[0].add_patch(rect)
rect = patches.Rectangle((12, -2000), 20, 700000, linewidth=2, edgecolor='blue', facecolor='cyan', alpha=0.1)
ax[1].add_patch(rect)
plt.subplots_adjust(hspace=0.3)      #This adjusts the space between the two plots
ax[0].set_ylabel('Intensity', fontsize=10)
ax[1].set_ylabel('Intensity', fontsize=10)

ax[0].legend(bbox_to_anchor=(1, 1.05), loc='upper left')
plt.tight_layout()
#plt.savefig('.png', dpi=300)

# %% [markdown]
# ### To Plot XRD Data with multiple zoomed in sections

# %%
directoryPath = os.path.join(r'')
data = pd.DataFrame()
i = 0
for file_name in glob.glob(directoryPath):
    ca_frac = (file_name.split('_1')[1]).split(".dat")[0]
    name = f"1/{ca_frac}"
    data[f"{name}"], data[f"{name}_y"] = np.loadtxt(file_name, usecols=(0,1), unpack=True)
    i+=1
    print(file_name)

# %%
plt.rcParams['font.family']='serif'
fig, ax = plt.subplots(3, 1, figsize=(16, 10))
plt.suptitle('Ca-doped P2 Series', fontsize=18)

#colours = pl.cm.Pastel1(4)
colours = ['orange','green','darkviolet', 'hotpink']
#(np.linspace(0,1,4))

for i in range(3):
    #ax[i].scatter(x, y_obs, s=0.2, color='black', label='Observed')
    for j in range(4):
        col = data.iloc[:,(1+(j*2))]
        ax[i].plot(x, col, linewidth=0.5, color=colours[j], label=col.name.split("_")[0])
    ax[i].set_xlabel(r'2$\theta$ / °', fontsize= 16)
    ax[i].yaxis.set_ticklabels([])
    ax[i].yaxis.set_ticks([])
ax[0].set_xlim(0, 70)
ax[1].set_xlim(7.75,9.25)
ax[1].set_ylim(-100, 5000000)
ax[2].set_xlim(16, 27)
ax[2].set_ylim(-100,800000)

#ax[0, 1].set_xlim(20, 35)
#ax[1, 1].set_xlim(35, 50)
#ax[0].set_facecolor('cyan', extent=(10, 20, 100, 300))
rect_1 = patches.Rectangle((7.75, -2000000), 1.5, 7500000, linewidth=2, edgecolor='hotpink', facecolor='pink', alpha=0.1)
ax[0].add_patch(rect_1)
rect_2 = patches.Rectangle((16, -2000000), 11, 7500000, linewidth=2, edgecolor='blue', facecolor='cyan', alpha=0.1)
ax[0].add_patch(rect_2)

rect_1 = patches.Rectangle((7.75, -2000000), 1.5, 75000000, linewidth=2, edgecolor='hotpink', facecolor='pink', alpha=0.1)
ax[1].add_patch(rect_1)
rect_2 = patches.Rectangle((16, -2000000), 11, 7500000, linewidth=2, edgecolor='blue', facecolor='cyan', alpha=0.1)
ax[2].add_patch(rect_2)

plt.subplots_adjust(hspace=0.3)      #This adjusts the space between the two plots
ax[0].set_ylabel('Intensity', fontsize=16)
ax[1].set_ylabel('Intensity', fontsize=16)
ax[2].set_ylabel('Intensity', fontsize=16)

ax[0].legend(bbox_to_anchor=(1, 1), loc='upper left', fontsize=16) #remove bbox section to put legen box inside data figure.
plt.tight_layout()
#plt.savefig(r'.png', dpi=300)

# %% [markdown]
# ### Plotting multiple XRD

# %%
import glob
import pandas as pd
import matplotlib.pylab as pl
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import seaborn as sns

# %%
directoryPath = os.path.join(r'')
data = pd.DataFrame()
#i = 0
for file_name in glob.glob(directoryPath):
    temp = (file_name.split('P2')[1]).split(".dat")[0]
    print(temp)
    name = f"{temp}°C"
    data[f"{name}"], data[f"{name}_y"] = np.loadtxt(file_name, usecols=(0,1), unpack=True)
    #i+=1
    print(file_name)

# %%
data
# Out:
#        temp_800     temp_800_y  temp_825     temp_825_y  temp_850  \
# 0         2.084  131507.733475     2.084  133743.353412     2.084
# 1         2.088  130635.052239     2.088  132518.014925     2.088
# 2         2.092  130350.332090     2.092  132808.958700     2.092
# 3         2.096  130449.291139     2.096  132809.326226     2.096
# 4         2.100  130246.759494     2.100  131559.859275     2.100
# ...         ...            ...       ...            ...       ...
# 22571    92.368   11561.975480    92.368   16718.033582    92.368
# 22572    92.372   11729.159073    92.372   16790.633094    92.372
# 22573    92.376   11526.134328    92.376   16687.820896    92.376
# 22574    92.380   11489.179104    92.380   16612.181237    92.380
# 22575    92.384   11474.036238    92.384   16853.331202    92.384
#
#           temp_850_y  temp_875     temp_875_y  temp_900     temp_900_y
# 0      134304.300640     2.084  131593.747335     2.084  130182.243603
# ...

# %%
plt.rcParams['font.family']='serif'
fig, ax = plt.subplots(2, 1, figsize=(16, 10))
plt.suptitle('Varied Temperature Synthesis', fontsize=18)

x = data["800°C"]
#y_obs = data[:, 1]
#y_calc = data[:, 2]

colours = sns.color_palette("Greys", 5)
#colours = pl.cm.Pastel1(4)
#colours = ['orange','green','darkviolet', 'hotpink', 'steelblue']

#(np.linspace(0,1,4))

for i in range(2):
    #ax[i].scatter(x, y_obs, s=0.2, color='black', label='Observed')
    for j in range(5):
        col = data.iloc[:,(1+(j*2))]
        ax[i].plot(x, col, linewidth=1.5, color=colours[j], label=col.name.split("_")[0])
    ax[i].set_xlabel(r'2$\theta$ / °', fontsize= 16)
    ax[i].yaxis.set_ticklabels([])
    ax[i].yaxis.set_ticks([])
ax[0].set_xlim(7, 45)
ax[1].set_xlim(16,27)
ax[1].set_ylim(-100, 500000)
#ax[2].set_xlim(16, 27)
#ax[2].set_ylim(-100,800000)

#ax[0, 1].set_xlim(20, 35)
#ax[1, 1].set_xlim(35, 50)
#ax[0].set_facecolor('cyan', extent=(10, 20, 100, 300))

#rect_1 = patches.Rectangle((7.75, -2000000), 1.5, 7500000, linewidth=2, edgecolor='hotpink', facecolor='pink', alpha=0.1)
#ax[0].add_patch(rect_1)
#rect_2 = patches.Rectangle((16, -2000000), 11, 7500000, linewidth=2, edgecolor='blue', facecolor='cyan', alpha=0.1)
#ax[0].add_patch(rect_2)

#rect_1 = patches.Rectangle((7.75, -2000000), 1.5, 75000000, linewidth=2, edgecolor='hotpink', facecolor='pink', alpha=0.1)
#ax[1].add_patch(rect_1)
#rect_2 = patches.Rectangle((16, -2000000), 11, 7500000, linewidth=2, edgecolor='blue', facecolor='cyan', alpha=0.1)
#ax[2].add_patch(rect_2)

#plt.subplots_adjust(hspace=0.3)      #This adjusts the space between the two plots
ax[0].set_ylabel('Intensity', fontsize=16)
ax[1].set_ylabel('Intensity', fontsize=16)
#ax[2].set_ylabel('Intensity', fontsize=16)

ax[0].legend(loc='upper right', fontsize=16) #remove bbox section to put legen box inside data figure.bbox_to_anchor=(1, 1),
ax[1].legend(loc='upper right', fontsize=16)
plt.tight_layout()
plt.savefig(r'.jpeg', dpi=300)

# %% [markdown]
# ### Plotting lattice parameters

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #### First load in your data

# %%
P2_Params = pd.read_excel(r'.xlsx')
P2_Params.head()
# Out:
#     Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0  Composition  Ca_content          a          c     volume         NaN
# 1           P2           0     2.8895    11.1589        NaN         NaN
# 2        P2_JS           0   2.891999  11.177331        NaN         NaN
# 3       Ca-119    0.052632   2.887615  11.161452        NaN         NaN
# 4       Ca-121    0.047619   2.887849  11.172342        NaN         NaN
#
#             Unnamed: 6 Unnamed: 7 Unnamed: 8 Compositions Unnamed: 10  \
# 0  Lattice Parameters      Ca1/19     Ca1/21       Ca1/25      Ca1/27
# 1                a (Å)     2.8876     2.8878       2.8884      2.8876
# 2                c (Å)     11.161     11.172       11.165      11.172
# 3     Cell Volume (Å3)     80.599     80.691       80.671      80.676
# 4                  NaN        NaN        NaN          NaN         NaN
#
#   Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# ...

# %% [markdown]
# #### In the csv/xlsx file beforehand I have loaded in the values which the rietveld analysis produced in the jEdit input file with column 1 = Ca_content, column 2 = a, column 3 = c.

# %% [markdown]
# #### Then I can just do axs[0].plot(P2_Params["Ca_content"], P2_Params["a"], "o", c="k") for the top graph and then run axs[1].plot(P2_Params["Ca_content"], P2_Params["c"], "o", c="b") to produce the second graph below which plots the c parameters.

# %%
#%matplotlib_inline #magic thing which bundles mat plot lib into notebooks and should allow saving figures whilst plt.show()
fig, axs = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(15, 10))
plt.rc("font", size=15)
fig.subplots_adjust(hspace=0.1)

axs[0].plot(P2_Params["Ca_content"], P2_Params["a"], "o", c="k")
axs[1].plot(P2_Params["Ca_content"], P2_Params["c"], "o", c="b")

axs[1].set_xlabel("Ca Content / mol %")
axs[0].set_ylabel("$a$-lattice Parameter / $\AA$")
axs[1].set_ylabel("$c$-lattice Parameter / $\AA$")

#axs[0].set_ylim(2.948, 2.958)
#axs[1].set_ylim(15.96, 16.06)

#plt.show()
#plt.savefig('.png', dpi=300)

# %%
dataset_name =
file_path = rf""
