# %% [markdown]
# ## Rate Capability Plotting

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from battery_characterisation_tool.echem_plotting.rate_capability_plotting import RateCapabilityPlotting
folder_path = rf""
dataset_name = "P2P3"
plot_title = "Rate Capability Plot"
active_mass_list = [0.01141, 0.01283, 0.01168, 0.01177, 0.01177, 0.01123]
legend_labels = ["P2P3", "NCNMO2/72", "NCNMO3/72", "P2", "P2Ca1/27", "P2Ca1/21"]
plot = RateCapabilityPlotting(folder_path = folder_path,
                            dataset_name = dataset_name,
                            plot_title = plot_title,
                            active_mass_list = active_mass_list,
                            legend_labels=legend_labels)
plot.rate_capability()
