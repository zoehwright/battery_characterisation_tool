# %% [markdown]
# ## Capacity Fade Plotting

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Capacity Fade with Coulombic Efficiency

# %%
from battery_characterisation_tool.echem_plotting.capacity_fade_plotting import CapacityFadePlotting
file_path = rf""
dataset_name = "P2"
plot_title = "P2-Na2/3Ni1/3Mn2/3O2 "
active_mass = 0.01230
plot = CapacityFadePlotting(file_path = file_path,
                            dataset_name = dataset_name,
                            plot_title = plot_title,
                            active_mass = active_mass)
plot.capacity_fade_ce()

# %% [markdown]
# ## Capacity Fade

# %%
from battery_characterisation_tool.echem_plotting.capacity_fade_plotting import CapacityFadePlotting
folder_path = rf""
dataset_name = "P2P3"
plot_title = "Capacity Fade Plot"
active_mass_list = [0.01141, 0.01239, 0.01123, 0.01221, 0.01141, 0.01105]
xlim = (-2, 60)
legend_labels = ["P2P3", "NCNMO2/72", "NCNMO3/72", "P2", "P2Ca1/27", "P2Ca1/21"]
plot = CapacityFadePlotting(folder_path = folder_path,
                            dataset_name = dataset_name,
                            plot_title = plot_title,
                            active_mass_list = active_mass_list,
                            #xlim = xlim,
                            legend_labels=legend_labels)
plot.capacity_fade()

# %% [markdown]
# ## VC Cycle Comparison

# %%
from battery_characterisation_tool.echem_plotting.capacity_fade_plotting import CapacityFadePlotting 
active_mass_list = [0.01114, 0.01239, 0.01123, 0.01221, 0.01141, 0.01105]
legend_labels = ["P2P3", "NCNMO2/72", "NCNMO3/72", "P2", "P2Ca1/27", "P2Ca1/21"]
plot_title = "Voltage Capacity 1st Cycle Comparison"
file_path = rf""

plot = CapacityFadePlotting(file_path=file_path, 
                            plot_title = plot_title, 
                            active_mass_list=active_mass_list, 
                            legend_labels=legend_labels)
plot.vc_cycle_comparison()

# %% [markdown]
# ## VC 50th Cycle Comparison

# %%
from battery_characterisation_tool.echem_plotting.capacity_fade_plotting import CapacityFadePlotting 
active_mass_list = [0.01114, 0.01239, 0.01123]
legend_labels = ["P2P3", "NCNMO2/72", "NCNMO3/72"]
plot_title = "P2P3 Voltage Capacity 50th Cycle Comparison"
file_path = rf""

plot = CapacityFadePlotting(file_path=file_path, 
                            plot_title = plot_title, 
                            active_mass_list=active_mass_list, 
                            legend_labels=legend_labels)
plot.vc_cycle_comparison()
