# %% [markdown]
# ## Raman Plotting

# %% [markdown]
# ### Single Raman Spectra Plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from battery_characterisation_tool.raman_plotting.raman_plotting import RamanPlot

dataset_name = r"240315_ZW_ELECTRODE_P2-Na0.67Ni0.33Mn0.67O2_633_20x10_1800acd.xy" #needs to be the .xy file name 
folder_path = rf"C:" #the folder with your .xy files in
figsize = (12,8)
plot_title = r"Raman Plot for P2-Na$_{2/3}$Ni$_{1/3}$Mn$_{2/3}$O$_2$ Electrode"
               
raman_plotting= RamanPlot(dataset_name=dataset_name,
                           folder_path = folder_path,
                           figsize = figsize,
                           plot_title = plot_title)

raman_plotting.raman_plot()

# %%
from battery_characterisation_tool.raman_plotting.raman_plotting import RamanPlot

dataset_name = r"xxx.xy" #this needs to be your .xy file name
folder_path = rf"C:"
figsize = (12,8)
plot_title = r"Raman Plot for P2Electrode"
               
raman_plotting= RamanPlot(dataset_name=dataset_name,
                           folder_path = folder_path,
                           figsize = figsize,
                           plot_title = plot_title)

raman_plotting.raman_plot()

# %% [markdown]
# ### Stacked Raman Plot

# %%
from battery_characterisation_tool.raman_plotting.raman_plotting import RamanPlot

folder_path = rf"" #the folder with your .xy files in
figsize = (12,8)
plot_title = "Raman Plot for P2-Na$_{2/3}$Ni$_{1/3}$Mn$_{2/3}$O$_2$ pristine & electrode"
legend_labels = ["P2 Powder", "P2 electrode"]
               
raman_plotting= RamanPlot(dataset_name=dataset_name,
                           folder_path = folder_path,
                           figsize = figsize,
                           plot_title = plot_title,
                           legend_labels= legend_labels)

raman_plotting.raman_stacked_plot()
